# %% [markdown]
# # OpenCV Cheat Sheet

# %% [markdown]
# ## Packages

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
# Load an color image in grayscale
img = cv2.imread('test.jpg',0)

# %%
img
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %% [markdown]
# ## Display image, wait for key press, then close windows

# %%
cv2.imshow('image',img)

# %%
cv2.waitKey(0)
# Out:
# 97

# %%
cv2.destroyAllWindows()

# %% [markdown]
# ## Below program loads an image in grayscale, displays it, save the image if you press ‘s’ and exit, or simply exit without saving if you press ESC key.

# %%
img = cv2.imread('test.jpg',0)
cv2.imshow('image',img)
k = cv2.waitKey(0) & 0xFF
if k == 27:         # wait for ESC key to exit
    cv2.destroyAllWindows()
elif k == ord('s'): # wait for 's' key to save and exit
    cv2.imwrite('test_resave.png',img)
    cv2.destroyAllWindows()

# %% [markdown]
# ## Use Matplotlib

# %%
img = cv2.imread('test.jpg',1)
# Grayscale: img = cv2.imread('test.jpg', 0)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
# Dimensions of image
img.shape
# Out:
# (334, 834, 3)

# %%
int(img.shape[0]/2)
# Out:
# 167

# %%
px = img [int((img.shape[0])/2),int((img.shape[1])/2)]
print (px)
# Out:
# [202 233  70]

# %%
print (px)
# Out:
# [255 255 255]

# %%
# Smooth image

img = cv2.imread('Feral_ghoul.png')

blur = cv2.blur(img,(5,5))

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
# Edge detection
img = cv2.imread('Feral_ghoul.png',0)
edges = cv2.Canny(img,100,200)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
img = cv2.imread('Feral_ghoul.png')
rows,cols,ch = img.shape
pts1 = np.float32([[56,65],[368,52],[28,387],[389,390]])
pts2 = np.float32([[0,0],[300,0],[0,300],[300,300]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(400,500))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('fear.jpg',1)
blur = cv2.blur(img,(50,50))
cv2.imshow('image',blur)
k = cv2.waitKey(0) & 0xFF
if k == 27:         # wait for ESC key to exit
    cv2.destroyAllWindows()
elif k == ord('s'): # wait for 's' key to save and exit
    cv2.imwrite('fear_resave.png',blur)
    cv2.destroyAllWindows()
